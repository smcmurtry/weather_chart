# %% [markdown]
# # Weather Visualization

# %% [markdown]
# Inspired by the NYT weather graphic:
#
# * Original: http://www.edwardtufte.com/bboard/q-and-a-fetch-msg?msg_id=00014g
# * Python (Matplotlib?) reinterpretation: http://www.randalolson.com/2015/08/13/the-new-york-times-weather-chart-redux/
# * New computer generated NYT version: http://customflowsolutions.com/wordpress/?p=107

# %%
from IPython.display import Image

# %%
img_1 = '00014g-836.jpg' # from 'http://www.edwardtufte.com/bboard/images/00014g-836.jpg'
img_2 = '0107-wea-NYCYEAR.png' # from 'http://www.nytimes.com/imagepages/2007/01/07/nyregion/20070107_NYC_GRAPHIC.html'

# %% [markdown]
# #### Original Print Version

# %%
Image(filename=img_1)

# %% [markdown]
# #### Updated Print Version

# %%
Image(filename=img_2)
